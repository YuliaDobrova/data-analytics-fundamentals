# %% [markdown]
# # Data Visualization

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **Introduction to Data Visualization**
#
# `Data visualization` is the process of presenting information and data in a graphical format. Utilizing visual elements such as charts, graphs, and maps, data visualization tools offer an intuitive approach to interpreting trends, outliers, and patterns within data.

# %%
# Import the matplotlib.pyplot module
import matplotlib.pyplot as plt
import pandas as pd

# Creating a sample DataFrame
df = pd.DataFrame({
    "a": [1,2,3,4,5],
    "b": [1,4,9,16,25]
})

# Plot the data points for (x, y)
plt.plot(df["a"], df["b"])

# Set the title of the plot
plt.title('My first plot/chart')

# Label the x-axis
plt.xlabel('A')

# Label the y-axis
plt.ylabel('B')

# Display the plot
plt.show()
# Out:
# 2024-06-20 19:59:45.146 system_profiler[53360:12033531] CoreText note: Client requested name ".AlBayanPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-06-20 19:59:45.146 system_profiler[53360:12033531] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2024-06-20 19:59:45.152 system_profiler[53360:12033531] CoreText note: Client requested name ".AlBayanPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# ...

# %% [markdown]
# ### Types of Charts
# - Bar
# - Pie
# - Line/Plot
# - Scatter

# %%
# Generating a bar chart (x, y)
plt.bar(df['a'], df['b'])

# Set the title of the plot
plt.title('My first bar chart')

# Label the x-axis
plt.xlabel('A')

# Label the y-axis
plt.ylabel('B')

# Display the plot
plt.show()

# %%
# Generating a pie chart (x)
plt.pie(df["b"], labels=df["b"], autopct="%1.1f%%")

# Set the title of the plot
plt.title('My first pie chart')

plt.show()

# %%
# Scatter chart (x, y)
plt.scatter(df["a"], df["b"])

# Set the title of the plot
plt.title('My first scatter chart')

# Label the x-axis
plt.xlabel('A')

# Label the y-axis
plt.ylabel('B')

plt.show()

# %%
# Subplots (show multiple plots at once)
f, (ax1, ax2) = plt.subplots(1, 2)

# %%
# Subplots (show multiple plots at once)
# 1 row and 2 columns (1, 2)
f, (ax1, ax2) = plt.subplots(1, 2)

# Line Chart
ax1.title.set_text('Line Chart')
ax1.plot(df["a"], df["b"])

# Pie Chart
ax2.title.set_text('Pie Chart')
ax2.pie(df["a"], labels=df["a"])

plt.show()

# %% [markdown]
# https://naledi.co.uk
#
# https://gerinberg.com
